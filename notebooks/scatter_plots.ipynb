# %%
# %matplotlib inline
from fitbittools.fbdata import FitBitData                                              
from fitbittools.plotters import Plotter
import pandas as pd

# %%
filename="/Users/frenchwr/Computing/Python/Fitbit/data/fitbit_export_20140710.csv"
fb_obj = FitBitData(filename)
activity = fb_obj.activity.pd_data
sleep = fb_obj.sleep.pd_data
allData = fb_obj.comp_pd_data

# %%
plotter = Plotter()
plotter.plot_data_frame(sleep,x='Minutes Asleep',y='Minutes Awake',kind='scatter')
plotter.plot_data_frame(sleep,x='Minutes Asleep',y='Number of Awakenings',kind='scatter')
plotter.plot_data_frame(sleep,x='Minutes Asleep',y='Time in Bed',kind='scatter')
plotter.plot_data_frame(sleep,x='Minutes Awake',y='Number of Awakenings',kind='scatter')
plotter.plot_data_frame(sleep,x='Minutes Awake',y='Time in Bed',kind='scatter')
plotter.plot_data_frame(sleep,x='Number of Awakenings',y='Time in Bed',kind='scatter')

# %%
plotter.plot_data_frame(activity,x='Steps',y='Calories Burned',kind='scatter')
plotter.plot_data_frame(activity,x='Steps',y='Distance',kind='scatter')
plotter.plot_data_frame(activity,x='Steps',y='Floors',kind='scatter')
plotter.plot_data_frame(activity,x='Steps',y='Minutes Sedentary',kind='scatter')
plotter.plot_data_frame(activity,x='Steps',y='Minutes Lightly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Steps',y='Minutes Fairly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Steps',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(activity,x='Steps',y='Activity Calories',kind='scatter')
plotter.plot_data_frame(activity,x='Calories Burned',y='Distance',kind='scatter')
plotter.plot_data_frame(activity,x='Calories Burned',y='Floors',kind='scatter')
plotter.plot_data_frame(activity,x='Calories Burned',y='Minutes Sedentary',kind='scatter')
plotter.plot_data_frame(activity,x='Calories Burned',y='Minutes Lightly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Calories Burned',y='Minutes Fairly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Calories Burned',y='Activity Calories',kind='scatter')
plotter.plot_data_frame(activity,x='Distance',y='Floors',kind='scatter')
plotter.plot_data_frame(activity,x='Distance',y='Minutes Sedentary',kind='scatter')
plotter.plot_data_frame(activity,x='Distance',y='Minutes Lightly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Distance',y='Minutes Fairly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Distance',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(activity,x='Distance',y='Activity Calories',kind='scatter')
plotter.plot_data_frame(activity,x='Floors',y='Minutes Sedentary',kind='scatter')
plotter.plot_data_frame(activity,x='Floors',y='Minutes Lightly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Floors',y='Minutes Fairly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Floors',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(activity,x='Floors',y='Activity Calories',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Sedentary',y='Minutes Lightly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Sedentary',y='Minutes Fairly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Sedentary',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Sedentary',y='Activity Calories',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Lightly Active',y='Minutes Fairly Active',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Fairly Active',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Fairly Active',y='Activity Calories',kind='scatter')
plotter.plot_data_frame(activity,x='Minutes Very Active',y='Activity Calories',kind='scatter')

# %%
plotter.plot_data_frame(allData,x='Minutes Asleep',y='Steps',kind='scatter')
plotter.plot_data_frame(allData,x='Minutes Awake',y='Steps',kind='scatter')
plotter.plot_data_frame(allData,x='Number of Awakenings',y='Steps',kind='scatter')
plotter.plot_data_frame(allData,x='Time in Bed',y='Steps',kind='scatter')
plotter.plot_data_frame(allData,x='Minutes Asleep',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(allData,x='Minutes Awake',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(allData,x='Number of Awakenings',y='Minutes Very Active',kind='scatter')
plotter.plot_data_frame(allData,x='Time in Bed',y='Minutes Very Active',kind='scatter')

# %%
plotter.plot_multi_data(allData,'Steps','Minutes Sedentary','Minutes Lightly Active','Minutes Fairly Active','Minutes Very Active')
plotter.plot_multi_data(allData,'Time in Bed','Minutes Asleep','Minutes Awake')
